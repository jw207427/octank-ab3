# %% [markdown]
# ## Set Up

# %%
# !pip install opencv-python
# !sudo yum update -y
# !sudo yum install ffmpeg libsm6 libxext6  -y
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from opencv-python) (1.20.3)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# neuron                                                   | 2.9 kB     00:00
# Resolving Dependencies
# --> Running transaction check
# ---> Package amazon-ssm-agent.x86_64 0:3.0.1124.0-1.amzn2 will be updated
# ---> Package amazon-ssm-agent.x86_64 0:3.1.1188.0-1.amzn2 will be an update
# ---> Package aws-neuron-tools.x86_64 0:2.0.623.0-1 will be updated
# ---> Package aws-neuron-tools.x86_64 0:2.1.4.0-1 will be an update
# ---> Package containerd.x86_64 0:1.4.13-2.amzn2.0.1 will be updated
# ---> Package containerd.x86_64 0:1.4.13-3.amzn2 will be an update
# ---> Package cpp.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package cpp.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package dhclient.x86_64 12:4.2.5-77.amzn2.1.5 will be updated
# ---> Package dhclient.x86_64 12:4.2.5-77.amzn2.1.6 will be an update
# ---> Package dhcp-common.x86_64 12:4.2.5-77.amzn2.1.5 will be updated
# ---> Package dhcp-common.x86_64 12:4.2.5-77.amzn2.1.6 will be an update
# ---> Package dhcp-libs.x86_64 12:4.2.5-77.amzn2.1.5 will be updated
# ---> Package dhcp-libs.x86_64 12:4.2.5-77.amzn2.1.6 will be an update
# ---> Package dracut.x86_64 0:033-535.amzn2.1.5 will be updated
# ---> Package dracut.x86_64 0:033-535.amzn2.1.6 will be an update
# ---> Package dracut-config-generic.x86_64 0:033-535.amzn2.1.5 will be updated
# ---> Package dracut-config-generic.x86_64 0:033-535.amzn2.1.6 will be an update
# ---> Package ec2-net-utils.noarch 0:1.6-1.amzn2 will be obsoleted
# ---> Package ec2-net-utils.noarch 0:1.6.1-2.amzn2 will be obsoleting
# ---> Package gcc.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package gcc.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package gcc-c++.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package gcc-c++.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package gcc-gfortran.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package gcc-gfortran.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package gnutls.x86_64 0:3.3.29-9.amzn2 will be updated
# ---> Package gnutls.x86_64 0:3.3.29-9.amzn2.0.1 will be an update
# ---> Package iproute.x86_64 0:5.10.0-2.amzn2.0.1 will be updated
# ---> Package iproute.x86_64 0:5.10.0-2.amzn2.0.2 will be an update
# ---> Package kernel-devel.x86_64 0:5.10.118-111.515.amzn2 will be installed
# ---> Package kernel-headers.x86_64 0:5.10.112-108.499.amzn2 will be updated
# ---> Package kernel-headers.x86_64 0:5.10.118-111.515.amzn2 will be an update
# ---> Package libatomic.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libatomic.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libcilkrts.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libcilkrts.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libgcc.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libgcc.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libgfortran.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libgfortran.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libgomp.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libgomp.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libitm.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libitm.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libmpx.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libmpx.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libnvidia-container-tools.x86_64 0:1.8.1-1 will be updated
# ---> Package libnvidia-container-tools.x86_64 0:1.10.0-1 will be an update
# ---> Package libnvidia-container1.x86_64 0:1.8.1-1 will be updated
# ---> Package libnvidia-container1.x86_64 0:1.10.0-1 will be an update
# ---> Package libquadmath.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libquadmath.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libsanitizer.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libsanitizer.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libstdc++.x86_64 0:7.3.1-14.amzn2 will be updated
# ---> Package libstdc++.x86_64 0:7.3.1-15.amzn2 will be an update
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.1 will be updated
# ---> Package libtiff.x86_64 0:4.0.3-35.amzn2.0.2 will be an update
# ---> Package log4j-cve-2021-44228-hotpatch.noarch 0:1.1-16.amzn2 will be updated
# ---> Package log4j-cve-2021-44228-hotpatch.noarch 0:1.3-5.amzn2 will be an update
# ---> Package microcode_ctl.x86_64 2:2.1-47.amzn2.0.11 will be updated
# ---> Package microcode_ctl.x86_64 2:2.1-47.amzn2.0.12 will be an update
# ---> Package nvidia-container-toolkit.x86_64 0:1.8.1-1 will be updated
# ---> Package nvidia-container-toolkit.x86_64 0:1.10.0-1 will be an update
# ---> Package nvidia-docker2.noarch 0:2.9.1-1 will be updated
# ---> Package nvidia-docker2.noarch 0:2.11.0-1 will be an update
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.2 will be updated
# ---> Package openssl.x86_64 1:1.0.2k-24.amzn2.0.3 will be an update
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.2 will be updated
# ---> Package openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.3 will be an update
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.2 will be updated
# ---> Package openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.3 will be an update
# ---> Package python.x86_64 0:2.7.18-1.amzn2.0.4 will be updated
# ---> Package python.x86_64 0:2.7.18-1.amzn2.0.5 will be an update
# ---> Package python-devel.x86_64 0:2.7.18-1.amzn2.0.4 will be updated
# ---> Package python-devel.x86_64 0:2.7.18-1.amzn2.0.5 will be an update
# ---> Package python-libs.x86_64 0:2.7.18-1.amzn2.0.4 will be updated
# ---> Package python-libs.x86_64 0:2.7.18-1.amzn2.0.5 will be an update
# ---> Package python2-rpm.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package python2-rpm.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm-build.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm-build.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm-build-libs.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm-build-libs.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm-libs.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm-libs.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm-plugin-systemd-inhibit.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm-plugin-systemd-inhibit.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rpm-sign.x86_64 0:4.11.3-40.amzn2.0.6 will be updated
# ---> Package rpm-sign.x86_64 0:4.11.3-48.amzn2.0.2 will be an update
# ---> Package rsyslog.x86_64 0:8.24.0-57.amzn2.1 will be updated
# ---> Package rsyslog.x86_64 0:8.24.0-57.amzn2.2.0.1 will be an update
# ---> Package runc.x86_64 0:1.0.0-2.amzn2 will be updated
# ---> Package runc.x86_64 0:1.0.3-3.amzn2 will be an update
# ---> Package selinux-policy.noarch 0:3.13.1-192.amzn2.6.7 will be updated
# ---> Package selinux-policy.noarch 0:3.13.1-192.amzn2.6.8 will be an update
# ---> Package selinux-policy-targeted.noarch 0:3.13.1-192.amzn2.6.7 will be updated
# ---> Package selinux-policy-targeted.noarch 0:3.13.1-192.amzn2.6.8 will be an update
# ---> Package sysctl-defaults.noarch 0:1.0-2.amzn2 will be updated
# ---> Package sysctl-defaults.noarch 0:1.0-3.amzn2 will be an update
# ---> Package system-rpm-config.noarch 0:9.1.0-76.amzn2.0.10 will be updated
# ---> Package system-rpm-config.noarch 0:9.1.0-76.amzn2.0.14 will be an update
# --> Processing Dependency: go-srpm-macros for package: system-rpm-config-9.1.0-76.amzn2.0.14.noarch
# ---> Package systemd.x86_64 0:219-78.amzn2.0.15 will be updated
# ---> Package systemd.x86_64 0:219-78.amzn2.0.18 will be an update
# ---> Package systemd-devel.x86_64 0:219-78.amzn2.0.15 will be updated
# ---> Package systemd-devel.x86_64 0:219-78.amzn2.0.18 will be an update
# ---> Package systemd-libs.x86_64 0:219-78.amzn2.0.15 will be updated
# ---> Package systemd-libs.x86_64 0:219-78.amzn2.0.18 will be an update
# ---> Package systemd-sysv.x86_64 0:219-78.amzn2.0.15 will be updated
# ---> Package systemd-sysv.x86_64 0:219-78.amzn2.0.18 will be an update
# ---> Package tzdata.noarch 0:2021e-1.amzn2 will be updated
# ---> Package tzdata.noarch 0:2022a-1.amzn2 will be an update
# ---> Package tzdata-java.noarch 0:2021e-1.amzn2 will be updated
# ---> Package tzdata-java.noarch 0:2022a-1.amzn2 will be an update
# ---> Package vim-common.x86_64 2:8.2.4428-1.amzn2.0.3 will be updated
# ---> Package vim-common.x86_64 2:8.2.4857-1.amzn2.0.1 will be an update
# ---> Package vim-data.noarch 2:8.2.4428-1.amzn2.0.3 will be updated
# ---> Package vim-data.noarch 2:8.2.4857-1.amzn2.0.1 will be an update
# ---> Package vim-enhanced.x86_64 2:8.2.4428-1.amzn2.0.3 will be updated
# ---> Package vim-enhanced.x86_64 2:8.2.4857-1.amzn2.0.1 will be an update
# ---> Package vim-filesystem.noarch 2:8.2.4428-1.amzn2.0.3 will be updated
# ---> Package vim-filesystem.noarch 2:8.2.4857-1.amzn2.0.1 will be an update
# ---> Package vim-minimal.x86_64 2:8.2.4428-1.amzn2.0.3 will be updated
# ---> Package vim-minimal.x86_64 2:8.2.4857-1.amzn2.0.1 will be an update
# --> Running transaction check
# ---> Package go-srpm-macros.noarch 0:3.0.15-23.amzn2.0.1 will be installed
# --> Finished Dependency Resolution
# --> Running transaction check
# ---> Package kernel-devel.x86_64 0:5.10.96-90.460.amzn2 will be erased
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package            Arch   Version                Repository               Size
# ================================================================================
# Installing:
#  ec2-net-utils      noarch 1.6.1-2.amzn2          amzn2-core               20 k
#      replacing  ec2-net-utils.noarch 1.6-1.amzn2
#  kernel-devel       x86_64 5.10.118-111.515.amzn2 amzn2extra-kernel-5.10   16 M
# Updating:
#  amazon-ssm-agent   x86_64 3.1.1188.0-1.amzn2     amzn2-core               27 M
#  aws-neuron-tools   x86_64 2.1.4.0-1              neuron                   28 M
#  containerd         x86_64 1.4.13-3.amzn2         amzn2extra-docker        23 M
#  cpp                x86_64 7.3.1-15.amzn2         amzn2-core              9.2 M
#  dhclient           x86_64 12:4.2.5-77.amzn2.1.6  amzn2-core              287 k
#  dhcp-common        x86_64 12:4.2.5-77.amzn2.1.6  amzn2-core              177 k
#  dhcp-libs          x86_64 12:4.2.5-77.amzn2.1.6  amzn2-core              132 k
#  dracut             x86_64 033-535.amzn2.1.6      amzn2-core              325 k
#  dracut-config-generic
#                     x86_64 033-535.amzn2.1.6      amzn2-core               57 k
#  gcc                x86_64 7.3.1-15.amzn2         amzn2-core               22 M
#  gcc-c++            x86_64 7.3.1-15.amzn2         amzn2-core               13 M
#  gcc-gfortran       x86_64 7.3.1-15.amzn2         amzn2-core               11 M
#  gnutls             x86_64 3.3.29-9.amzn2.0.1     amzn2-core              661 k
#  iproute            x86_64 5.10.0-2.amzn2.0.2     amzn2-core              649 k
#  kernel-headers     x86_64 5.10.118-111.515.amzn2 amzn2extra-kernel-5.10  1.4 M
#  libatomic          x86_64 7.3.1-15.amzn2         amzn2-core               46 k
#  libcilkrts         x86_64 7.3.1-15.amzn2         amzn2-core               85 k
#  libgcc             x86_64 7.3.1-15.amzn2         amzn2-core               98 k
#  libgfortran        x86_64 7.3.1-15.amzn2         amzn2-core              536 k
#  libgomp            x86_64 7.3.1-15.amzn2         amzn2-core              204 k
#  libitm             x86_64 7.3.1-15.amzn2         amzn2-core               85 k
#  libmpx             x86_64 7.3.1-15.amzn2         amzn2-core               51 k
#  libnvidia-container-tools
#                     x86_64 1.10.0-1               libnvidia-container      49 k
#  libnvidia-container1
#                     x86_64 1.10.0-1               libnvidia-container     1.0 M
#  libquadmath        x86_64 7.3.1-15.amzn2         amzn2-core              189 k
#  libsanitizer       x86_64 7.3.1-15.amzn2         amzn2-core              642 k
#  libstdc++          x86_64 7.3.1-15.amzn2         amzn2-core              445 k
#  libtiff            x86_64 4.0.3-35.amzn2.0.2     amzn2-core              173 k
#  log4j-cve-2021-44228-hotpatch
#                     noarch 1.3-5.amzn2            amzn2-core              139 k
#  microcode_ctl      x86_64 2:2.1-47.amzn2.0.12    amzn2-core              298 k
#  nvidia-container-toolkit
#                     x86_64 1.10.0-1               libnvidia-container     3.1 M
#  nvidia-docker2     noarch 2.11.0-1               libnvidia-container     8.7 k
#  openssl            x86_64 1:1.0.2k-24.amzn2.0.3  amzn2-core              496 k
#  openssl-devel      x86_64 1:1.0.2k-24.amzn2.0.3  amzn2-core              1.5 M
#  openssl-libs       x86_64 1:1.0.2k-24.amzn2.0.3  amzn2-core              1.2 M
#  python             x86_64 2.7.18-1.amzn2.0.5     amzn2-core               93 k
#  python-devel       x86_64 2.7.18-1.amzn2.0.5     amzn2-core              403 k
#  python-libs        x86_64 2.7.18-1.amzn2.0.5     amzn2-core              7.5 M
#  python2-rpm        x86_64 4.11.3-48.amzn2.0.2    amzn2-core               85 k
#  rpm                x86_64 4.11.3-48.amzn2.0.2    amzn2-core              1.2 M
#  rpm-build          x86_64 4.11.3-48.amzn2.0.2    amzn2-core              150 k
#  rpm-build-libs     x86_64 4.11.3-48.amzn2.0.2    amzn2-core              107 k
#  rpm-libs           x86_64 4.11.3-48.amzn2.0.2    amzn2-core              277 k
#  rpm-plugin-systemd-inhibit
#                     x86_64 4.11.3-48.amzn2.0.2    amzn2-core               48 k
#  rpm-sign           x86_64 4.11.3-48.amzn2.0.2    amzn2-core               50 k
#  rsyslog            x86_64 8.24.0-57.amzn2.2.0.1  amzn2-core              619 k
#  runc               x86_64 1.0.3-3.amzn2          amzn2extra-docker       3.0 M
#  selinux-policy     noarch 3.13.1-192.amzn2.6.8   amzn2-core              456 k
#  selinux-policy-targeted
#                     noarch 3.13.1-192.amzn2.6.8   amzn2-core              6.6 M
#  sysctl-defaults    noarch 1.0-3.amzn2            amzn2-core              3.9 k
#  system-rpm-config  noarch 9.1.0-76.amzn2.0.14    amzn2-core               90 k
#  systemd            x86_64 219-78.amzn2.0.18      amzn2-core              5.0 M
#  systemd-devel      x86_64 219-78.amzn2.0.18      amzn2-core              216 k
#  systemd-libs       x86_64 219-78.amzn2.0.18      amzn2-core              408 k
#  systemd-sysv       x86_64 219-78.amzn2.0.18      amzn2-core               98 k
#  tzdata             noarch 2022a-1.amzn2          amzn2-core              484 k
#  tzdata-java        noarch 2022a-1.amzn2          amzn2-core              190 k
#  vim-common         x86_64 2:8.2.4857-1.amzn2.0.1 amzn2-core              7.5 M
#  vim-data           noarch 2:8.2.4857-1.amzn2.0.1 amzn2-core               75 k
#  vim-enhanced       x86_64 2:8.2.4857-1.amzn2.0.1 amzn2-core              1.6 M
#  vim-filesystem     noarch 2:8.2.4857-1.amzn2.0.1 amzn2-core               70 k
#  vim-minimal        x86_64 2:8.2.4857-1.amzn2.0.1 amzn2-core              686 k
# Removing:
#  kernel-devel       x86_64 5.10.96-90.460.amzn2   @amzn2extra-kernel-5.10  76 M
# Installing for dependencies:
#  go-srpm-macros     noarch 3.0.15-23.amzn2.0.1    amzn2-core               23 k
#
# Transaction Summary
# ================================================================================
# Install   2 Packages (+1 Dependent package)
# Upgrade  62 Packages
# Remove    1 Package
#
# Total download size: 199 M
# Downloading packages:
# Delta RPMs disabled because /usr/bin/applydeltarpm not installed.
# (1/65): cpp-7.3.1-15.amzn2.x86_64.rpm                      | 9.2 MB   00:00
# (2/65): dhclient-4.2.5-77.amzn2.1.6.x86_64.rpm             | 287 kB   00:00
# (3/65): dhcp-common-4.2.5-77.amzn2.1.6.x86_64.rpm          | 177 kB   00:00
# (4/65): dhcp-libs-4.2.5-77.amzn2.1.6.x86_64.rpm            | 132 kB   00:00
# (5/65): dracut-033-535.amzn2.1.6.x86_64.rpm                | 325 kB   00:00
# (6/65): dracut-config-generic-033-535.amzn2.1.6.x86_64.rpm |  57 kB   00:00
# (7/65): ec2-net-utils-1.6.1-2.amzn2.noarch.rpm             |  20 kB   00:00
# (8/65): aws-neuron-tools-2.1.4.0.rpm                       |  28 MB   00:00
# (9/65): containerd-1.4.13-3.amzn2.x86_64.rpm               |  23 MB   00:01
# (10/65): amazon-ssm-agent-3.1.1188.0-1.amzn2.x86_64.rpm    |  27 MB   00:01
# (11/65): gcc-7.3.1-15.amzn2.x86_64.rpm                     |  22 MB   00:00
# (12/65): gcc-c++-7.3.1-15.amzn2.x86_64.rpm                 |  13 MB   00:00
# (13/65): gnutls-3.3.29-9.amzn2.0.1.x86_64.rpm              | 661 kB   00:00
# (14/65): gcc-gfortran-7.3.1-15.amzn2.x86_64.rpm            |  11 MB   00:00
# (15/65): go-srpm-macros-3.0.15-23.amzn2.0.1.noarch.rpm     |  23 kB   00:00
# (16/65): libatomic-7.3.1-15.amzn2.x86_64.rpm               |  46 kB   00:00
# (17/65): libcilkrts-7.3.1-15.amzn2.x86_64.rpm              |  85 kB   00:00
# (18/65): libgcc-7.3.1-15.amzn2.x86_64.rpm                  |  98 kB   00:00
# (19/65): libgfortran-7.3.1-15.amzn2.x86_64.rpm             | 536 kB   00:00
# (20/65): iproute-5.10.0-2.amzn2.0.2.x86_64.rpm             | 649 kB   00:00
# (21/65): libgomp-7.3.1-15.amzn2.x86_64.rpm                 | 204 kB   00:00
# (22/65): libitm-7.3.1-15.amzn2.x86_64.rpm                  |  85 kB   00:00
# (23/65): kernel-headers-5.10.118-111.515.amzn2.x86_64.rpm  | 1.4 MB   00:00
# (24/65): libmpx-7.3.1-15.amzn2.x86_64.rpm                  |  51 kB   00:00
# (25/65): libquadmath-7.3.1-15.amzn2.x86_64.rpm             | 189 kB   00:00
# (26/65): libsanitizer-7.3.1-15.amzn2.x86_64.rpm            | 642 kB   00:00
# (27/65): libstdc++-7.3.1-15.amzn2.x86_64.rpm               | 445 kB   00:00
# (28/65): libtiff-4.0.3-35.amzn2.0.2.x86_64.rpm             | 173 kB   00:00
# (29/65): microcode_ctl-2.1-47.amzn2.0.12.x86_64.rpm        | 298 kB   00:00
# (30/65): log4j-cve-2021-44228-hotpatch-1.3-5.amzn2.noarch. | 139 kB   00:00
# (31/65): libnvidia-container-tools-1.10.0-1.x86_64.rpm     |  49 kB   00:00
# (32/65): libnvidia-container1-1.10.0-1.x86_64.rpm          | 1.0 MB   00:00
# (33/65): nvidia-container-toolkit-1.10.0-1.x86_64.rpm      | 3.1 MB   00:00
# (34/65): openssl-1.0.2k-24.amzn2.0.3.x86_64.rpm            | 496 kB   00:00
# (35/65): kernel-devel-5.10.118-111.515.amzn2.x86_64.rpm    |  16 MB   00:00
# (36/65): openssl-libs-1.0.2k-24.amzn2.0.3.x86_64.rpm       | 1.2 MB   00:00
# (37/65): nvidia-docker2-2.11.0-1.noarch.rpm                | 8.7 kB   00:00
# (38/65): python-2.7.18-1.amzn2.0.5.x86_64.rpm              |  93 kB   00:00
# (39/65): python-devel-2.7.18-1.amzn2.0.5.x86_64.rpm        | 403 kB   00:00
# (40/65): openssl-devel-1.0.2k-24.amzn2.0.3.x86_64.rpm      | 1.5 MB   00:00
# (41/65): python2-rpm-4.11.3-48.amzn2.0.2.x86_64.rpm        |  85 kB   00:00
# (42/65): rpm-4.11.3-48.amzn2.0.2.x86_64.rpm                | 1.2 MB   00:00
# (43/65): rpm-build-4.11.3-48.amzn2.0.2.x86_64.rpm          | 150 kB   00:00
# (44/65): rpm-build-libs-4.11.3-48.amzn2.0.2.x86_64.rpm     | 107 kB   00:00
# (45/65): rpm-libs-4.11.3-48.amzn2.0.2.x86_64.rpm           | 277 kB   00:00
# (46/65): rpm-plugin-systemd-inhibit-4.11.3-48.amzn2.0.2.x8 |  48 kB   00:00
# (47/65): rpm-sign-4.11.3-48.amzn2.0.2.x86_64.rpm           |  50 kB   00:00
# (48/65): python-libs-2.7.18-1.amzn2.0.5.x86_64.rpm         | 7.5 MB   00:00
# (49/65): rsyslog-8.24.0-57.amzn2.2.0.1.x86_64.rpm          | 619 kB   00:00
# (50/65): selinux-policy-3.13.1-192.amzn2.6.8.noarch.rpm    | 456 kB   00:00
# (51/65): sysctl-defaults-1.0-3.amzn2.noarch.rpm            | 3.9 kB   00:00
# (52/65): system-rpm-config-9.1.0-76.amzn2.0.14.noarch.rpm  |  90 kB   00:00
# (53/65): runc-1.0.3-3.amzn2.x86_64.rpm                     | 3.0 MB   00:00
# (54/65): selinux-policy-targeted-3.13.1-192.amzn2.6.8.noar | 6.6 MB   00:00
# (55/65): systemd-219-78.amzn2.0.18.x86_64.rpm              | 5.0 MB   00:00
# (56/65): systemd-devel-219-78.amzn2.0.18.x86_64.rpm        | 216 kB   00:00
# (57/65): systemd-libs-219-78.amzn2.0.18.x86_64.rpm         | 408 kB   00:00
# (58/65): systemd-sysv-219-78.amzn2.0.18.x86_64.rpm         |  98 kB   00:00
# (59/65): tzdata-java-2022a-1.amzn2.noarch.rpm              | 190 kB   00:00
# (60/65): tzdata-2022a-1.amzn2.noarch.rpm                   | 484 kB   00:00
# (61/65): vim-data-8.2.4857-1.amzn2.0.1.noarch.rpm          |  75 kB   00:00
# (62/65): vim-enhanced-8.2.4857-1.amzn2.0.1.x86_64.rpm      | 1.6 MB   00:00
# (63/65): vim-filesystem-8.2.4857-1.amzn2.0.1.noarch.rpm    |  70 kB   00:00
# (64/65): vim-minimal-8.2.4857-1.amzn2.0.1.x86_64.rpm       | 686 kB   00:00
# (65/65): vim-common-8.2.4857-1.amzn2.0.1.x86_64.rpm        | 7.5 MB   00:00
# --------------------------------------------------------------------------------
# Total                                               60 MB/s | 199 MB  00:03
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Updating   : libgcc-7.3.1-15.amzn2.x86_64                               1/129
#   Updating   : rpm-4.11.3-48.amzn2.0.2.x86_64                             2/129
#   Updating   : rpm-libs-4.11.3-48.amzn2.0.2.x86_64                        3/129
#   Updating   : systemd-libs-219-78.amzn2.0.18.x86_64                      4/129
#   Updating   : systemd-219-78.amzn2.0.18.x86_64                           5/129
#   Updating   : libstdc++-7.3.1-15.amzn2.x86_64                            6/129
#   Updating   : 1:openssl-libs-1.0.2k-24.amzn2.0.3.x86_64                  7/129
#   Updating   : python-libs-2.7.18-1.amzn2.0.5.x86_64                      8/129
#   Updating   : python-2.7.18-1.amzn2.0.5.x86_64                           9/129
#   Updating   : rpm-build-libs-4.11.3-48.amzn2.0.2.x86_64                 10/129
#   Updating   : 12:dhcp-libs-4.2.5-77.amzn2.1.6.x86_64                    11/129
#   Installing : go-srpm-macros-3.0.15-23.amzn2.0.1.noarch                 12/129
#   Updating   : system-rpm-config-9.1.0-76.amzn2.0.14.noarch              13/129
#   Updating   : libquadmath-7.3.1-15.amzn2.x86_64                         14/129
#   Updating   : iproute-5.10.0-2.amzn2.0.2.x86_64                         15/129
#   Updating   : 2:vim-data-8.2.4857-1.amzn2.0.1.noarch                    16/129
#   Updating   : libgfortran-7.3.1-15.amzn2.x86_64                         17/129
#   Updating   : 12:dhcp-common-4.2.5-77.amzn2.1.6.x86_64                  18/129
#   Updating   : 12:dhclient-4.2.5-77.amzn2.1.6.x86_64                     19/129
#   Updating   : libsanitizer-7.3.1-15.amzn2.x86_64                        20/129
#   Updating   : libcilkrts-7.3.1-15.amzn2.x86_64                          21/129
#   Updating   : dracut-033-535.amzn2.1.6.x86_64                           22/129
#   Updating   : libmpx-7.3.1-15.amzn2.x86_64                              23/129
#   Updating   : cpp-7.3.1-15.amzn2.x86_64                                 24/129
#   Updating   : libgomp-7.3.1-15.amzn2.x86_64                             25/129
#   Updating   : libitm-7.3.1-15.amzn2.x86_64                              26/129
#   Updating   : selinux-policy-3.13.1-192.amzn2.6.8.noarch                27/129
#   Updating   : 2:vim-filesystem-8.2.4857-1.amzn2.0.1.noarch              28/129
#   Updating   : 2:vim-common-8.2.4857-1.amzn2.0.1.x86_64                  29/129
#   Updating   : libatomic-7.3.1-15.amzn2.x86_64                           30/129
#   Updating   : gcc-7.3.1-15.amzn2.x86_64                                 31/129
#   Updating   : runc-1.0.3-3.amzn2.x86_64                                 32/129
#   Updating   : libnvidia-container1-1.10.0-1.x86_64                      33/129
#   Updating   : libnvidia-container-tools-1.10.0-1.x86_64                 34/129
#   Updating   : nvidia-container-toolkit-1.10.0-1.x86_64                  35/129
#   Updating   : nvidia-docker2-2.11.0-1.noarch                            36/129
#   Updating   : containerd-1.4.13-3.amzn2.x86_64                          37/129
#   Updating   : gcc-c++-7.3.1-15.amzn2.x86_64                             38/129
#   Updating   : gcc-gfortran-7.3.1-15.amzn2.x86_64                        39/129
#   Updating   : 2:vim-enhanced-8.2.4857-1.amzn2.0.1.x86_64                40/129
#   Updating   : selinux-policy-targeted-3.13.1-192.amzn2.6.8.noarch       41/129
#   Updating   : dracut-config-generic-033-535.amzn2.1.6.x86_64            42/129
#   Installing : ec2-net-utils-1.6.1-2.amzn2.noarch                        43/129
#   Updating   : 2:vim-minimal-8.2.4857-1.amzn2.0.1.x86_64                 44/129
#   Updating   : rpm-build-4.11.3-48.amzn2.0.2.x86_64                      45/129
#   Updating   : rpm-sign-4.11.3-48.amzn2.0.2.x86_64                       46/129
#   Updating   : python2-rpm-4.11.3-48.amzn2.0.2.x86_64                    47/129
#   Updating   : python-devel-2.7.18-1.amzn2.0.5.x86_64                    48/129
#   Updating   : systemd-sysv-219-78.amzn2.0.18.x86_64                     49/129
#   Updating   : 1:openssl-devel-1.0.2k-24.amzn2.0.3.x86_64                50/129
#   Updating   : 1:openssl-1.0.2k-24.amzn2.0.3.x86_64                      51/129
#   Updating   : libtiff-4.0.3-35.amzn2.0.2.x86_64                         52/129
#   Updating   : 2:microcode_ctl-2.1-47.amzn2.0.12.x86_64                  53/129
#   Updating   : rsyslog-8.24.0-57.amzn2.2.0.1.x86_64                      54/129
#   Updating   : systemd-devel-219-78.amzn2.0.18.x86_64                    55/129
#   Updating   : amazon-ssm-agent-3.1.1188.0-1.amzn2.x86_64                56/129
#   Updating   : rpm-plugin-systemd-inhibit-4.11.3-48.amzn2.0.2.x86_64     57/129
#   Installing : kernel-devel-5.10.118-111.515.amzn2.x86_64                58/129
#   Updating   : sysctl-defaults-1.0-3.amzn2.noarch                        59/129
#   Updating   : kernel-headers-5.10.118-111.515.amzn2.x86_64              60/129
#   Updating   : aws-neuron-tools-2.1.4.0-1.x86_64                         61/129
#   Updating   : log4j-cve-2021-44228-hotpatch-1.3-5.amzn2.noarch          62/129
#   Updating   : tzdata-java-2022a-1.amzn2.noarch                          63/129
#   Updating   : gnutls-3.3.29-9.amzn2.0.1.x86_64                          64/129
#   Updating   : tzdata-2022a-1.amzn2.noarch                               65/129
#   Cleanup    : ec2-net-utils-1.6-1.amzn2.noarch                          66/129
#   Cleanup    : 12:dhclient-4.2.5-77.amzn2.1.5.x86_64                     67/129
#   Cleanup    : systemd-devel-219-78.amzn2.0.15.x86_64                    68/129
#   Cleanup    : python-devel-2.7.18-1.amzn2.0.4.x86_64                    69/129
#   Cleanup    : systemd-sysv-219-78.amzn2.0.15.x86_64                     70/129
#   Cleanup    : 12:dhcp-common-4.2.5-77.amzn2.1.5.x86_64                  71/129
#   Cleanup    : 12:dhcp-libs-4.2.5-77.amzn2.1.5.x86_64                    72/129
#   Cleanup    : amazon-ssm-agent-3.0.1124.0-1.amzn2.x86_64                73/129
#   Cleanup    : dracut-config-generic-033-535.amzn2.1.5.x86_64            74/129
#   Cleanup    : selinux-policy-targeted-3.13.1-192.amzn2.6.7.noarch       75/129
#   Cleanup    : nvidia-docker2-2.9.1-1.noarch                             76/129
#   Cleanup    : nvidia-container-toolkit-1.8.1-1.x86_64                   77/129
#   Cleanup    : 1:openssl-devel-1.0.2k-24.amzn2.0.2.x86_64                78/129
#   Cleanup    : python2-rpm-4.11.3-40.amzn2.0.6.x86_64                    79/129
#   Cleanup    : rpm-build-4.11.3-40.amzn2.0.6.x86_64                      80/129
#   Cleanup    : rsyslog-8.24.0-57.amzn2.1.x86_64                          81/129
#   Cleanup    : dracut-033-535.amzn2.1.5.x86_64                           82/129
#   Cleanup    : gcc-gfortran-7.3.1-14.amzn2.x86_64                        83/129
#   Cleanup    : libgfortran-7.3.1-14.amzn2.x86_64                         84/129
#   Cleanup    : rpm-sign-4.11.3-40.amzn2.0.6.x86_64                       85/129
#   Cleanup    : gcc-c++-7.3.1-14.amzn2.x86_64                             86/129
#   Cleanup    : gcc-7.3.1-14.amzn2.x86_64                                 87/129
#   Cleanup    : libcilkrts-7.3.1-14.amzn2.x86_64                          88/129
#   Cleanup    : libsanitizer-7.3.1-14.amzn2.x86_64                        89/129
#   Cleanup    : libtiff-4.0.3-35.amzn2.0.1.x86_64                         90/129
#   Cleanup    : system-rpm-config-9.1.0-76.amzn2.0.10.noarch              91/129
#   Cleanup    : selinux-policy-3.13.1-192.amzn2.6.7.noarch                92/129
#   Cleanup    : sysctl-defaults-1.0-2.amzn2.noarch                        93/129
#   Cleanup    : kernel-headers-5.10.112-108.499.amzn2.x86_64              94/129
#   Cleanup    : aws-neuron-tools-2.0.623.0-1.x86_64                       95/129
#   Cleanup    : log4j-cve-2021-44228-hotpatch-1.1-16.amzn2.noarch         96/129
#   Cleanup    : tzdata-java-2021e-1.amzn2.noarch                          97/129
#   Cleanup    : kernel-devel-5.10.96-90.460.amzn2.x86_64                  98/129
#   Cleanup    : tzdata-2021e-1.amzn2.noarch                               99/129
#   Cleanup    : libstdc++-7.3.1-14.amzn2.x86_64                          100/129
#   Cleanup    : rpm-build-libs-4.11.3-40.amzn2.0.6.x86_64                101/129
#   Cleanup    : python-2.7.18-1.amzn2.0.4.x86_64                         102/129
#   Cleanup    : python-libs-2.7.18-1.amzn2.0.4.x86_64                    103/129
#   Cleanup    : libnvidia-container-tools-1.8.1-1.x86_64                 104/129
#   Cleanup    : 2:vim-minimal-8.2.4428-1.amzn2.0.3.x86_64                105/129
#   Cleanup    : rpm-plugin-systemd-inhibit-4.11.3-40.amzn2.0.6.x86_64    106/129
#   Cleanup    : rpm-libs-4.11.3-40.amzn2.0.6.x86_64                      107/129
#   Cleanup    : rpm-4.11.3-40.amzn2.0.6.x86_64                           108/129
#   Cleanup    : containerd-1.4.13-2.amzn2.0.1.x86_64                     109/129
#   Cleanup    : 2:vim-enhanced-8.2.4428-1.amzn2.0.3.x86_64               110/129
#   Cleanup    : 2:vim-common-8.2.4428-1.amzn2.0.3.x86_64                 111/129
#   Cleanup    : 1:openssl-1.0.2k-24.amzn2.0.2.x86_64                     112/129
#   Cleanup    : 2:microcode_ctl-2.1-47.amzn2.0.11.x86_64                 113/129
#   Cleanup    : 2:vim-data-8.2.4428-1.amzn2.0.3.noarch                   114/129
#   Cleanup    : 2:vim-filesystem-8.2.4428-1.amzn2.0.3.noarch             115/129
#   Cleanup    : systemd-219-78.amzn2.0.15.x86_64                         116/129
#   Cleanup    : systemd-libs-219-78.amzn2.0.15.x86_64                    117/129
#   Cleanup    : libgcc-7.3.1-14.amzn2.x86_64                             118/129
#   Cleanup    : 1:openssl-libs-1.0.2k-24.amzn2.0.2.x86_64                119/129
#   Cleanup    : runc-1.0.0-2.amzn2.x86_64                                120/129
#   Cleanup    : libnvidia-container1-1.8.1-1.x86_64                      121/129
#   Cleanup    : cpp-7.3.1-14.amzn2.x86_64                                122/129
#   Cleanup    : libatomic-7.3.1-14.amzn2.x86_64                          123/129
#   Cleanup    : libgomp-7.3.1-14.amzn2.x86_64                            124/129
#   Cleanup    : libitm-7.3.1-14.amzn2.x86_64                             125/129
#   Cleanup    : libmpx-7.3.1-14.amzn2.x86_64                             126/129
#   Cleanup    : libquadmath-7.3.1-14.amzn2.x86_64                        127/129
#   Cleanup    : iproute-5.10.0-2.amzn2.0.1.x86_64                        128/129
#   Cleanup    : gnutls-3.3.29-9.amzn2.x86_64                             129/129
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.3.x86_64                 1/129
#   Verifying  : nvidia-docker2-2.11.0-1.noarch                             2/129
#   Verifying  : selinux-policy-targeted-3.13.1-192.amzn2.6.8.noarch        3/129
#   Verifying  : libnvidia-container1-1.10.0-1.x86_64                       4/129
#   Verifying  : libtiff-4.0.3-35.amzn2.0.2.x86_64                          5/129
#   Verifying  : 12:dhcp-libs-4.2.5-77.amzn2.1.6.x86_64                     6/129
#   Verifying  : runc-1.0.3-3.amzn2.x86_64                                  7/129
#   Verifying  : tzdata-2022a-1.amzn2.noarch                                8/129
#   Verifying  : dracut-config-generic-033-535.amzn2.1.6.x86_64             9/129
#   Verifying  : 2:microcode_ctl-2.1-47.amzn2.0.12.x86_64                  10/129
#   Verifying  : rpm-build-4.11.3-48.amzn2.0.2.x86_64                      11/129
#   Verifying  : gnutls-3.3.29-9.amzn2.0.1.x86_64                          12/129
#   Verifying  : 12:dhclient-4.2.5-77.amzn2.1.6.x86_64                     13/129
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.3.x86_64                      14/129
#   Verifying  : 2:vim-enhanced-8.2.4857-1.amzn2.0.1.x86_64                15/129
#   Verifying  : libsanitizer-7.3.1-15.amzn2.x86_64                        16/129
#   Verifying  : rsyslog-8.24.0-57.amzn2.2.0.1.x86_64                      17/129
#   Verifying  : 1:openssl-libs-1.0.2k-24.amzn2.0.3.x86_64                 18/129
#   Verifying  : libatomic-7.3.1-15.amzn2.x86_64                           19/129
#   Verifying  : gcc-c++-7.3.1-15.amzn2.x86_64                             20/129
#   Verifying  : 2:vim-data-8.2.4857-1.amzn2.0.1.noarch                    21/129
#   Verifying  : system-rpm-config-9.1.0-76.amzn2.0.14.noarch              22/129
#   Verifying  : go-srpm-macros-3.0.15-23.amzn2.0.1.noarch                 23/129
#   Verifying  : rpm-libs-4.11.3-48.amzn2.0.2.x86_64                       24/129
#   Verifying  : systemd-219-78.amzn2.0.18.x86_64                          25/129
#   Verifying  : python-devel-2.7.18-1.amzn2.0.5.x86_64                    26/129
#   Verifying  : 2:vim-filesystem-8.2.4857-1.amzn2.0.1.noarch              27/129
#   Verifying  : tzdata-java-2022a-1.amzn2.noarch                          28/129
#   Verifying  : systemd-devel-219-78.amzn2.0.18.x86_64                    29/129
#   Verifying  : rpm-sign-4.11.3-48.amzn2.0.2.x86_64                       30/129
#   Verifying  : gcc-gfortran-7.3.1-15.amzn2.x86_64                        31/129
#   Verifying  : 2:vim-common-8.2.4857-1.amzn2.0.1.x86_64                  32/129
#   Verifying  : rpm-4.11.3-48.amzn2.0.2.x86_64                            33/129
#   Verifying  : containerd-1.4.13-3.amzn2.x86_64                          34/129
#   Verifying  : python-2.7.18-1.amzn2.0.5.x86_64                          35/129
#   Verifying  : log4j-cve-2021-44228-hotpatch-1.3-5.amzn2.noarch          36/129
#   Verifying  : libstdc++-7.3.1-15.amzn2.x86_64                           37/129
#   Verifying  : libgfortran-7.3.1-15.amzn2.x86_64                         38/129
#   Verifying  : python2-rpm-4.11.3-48.amzn2.0.2.x86_64                    39/129
#   Verifying  : systemd-sysv-219-78.amzn2.0.18.x86_64                     40/129
#   Verifying  : iproute-5.10.0-2.amzn2.0.2.x86_64                         41/129
#   Verifying  : ec2-net-utils-1.6.1-2.amzn2.noarch                        42/129
#   Verifying  : selinux-policy-3.13.1-192.amzn2.6.8.noarch                43/129
#   Verifying  : python-libs-2.7.18-1.amzn2.0.5.x86_64                     44/129
#   Verifying  : libitm-7.3.1-15.amzn2.x86_64                              45/129
#   Verifying  : libnvidia-container-tools-1.10.0-1.x86_64                 46/129
#   Verifying  : aws-neuron-tools-2.1.4.0-1.x86_64                         47/129
#   Verifying  : rpm-build-libs-4.11.3-48.amzn2.0.2.x86_64                 48/129
#   Verifying  : libgcc-7.3.1-15.amzn2.x86_64                              49/129
#   Verifying  : libcilkrts-7.3.1-15.amzn2.x86_64                          50/129
#   Verifying  : kernel-headers-5.10.118-111.515.amzn2.x86_64              51/129
#   Verifying  : libgomp-7.3.1-15.amzn2.x86_64                             52/129
#   Verifying  : sysctl-defaults-1.0-3.amzn2.noarch                        53/129
#   Verifying  : libquadmath-7.3.1-15.amzn2.x86_64                         54/129
#   Verifying  : cpp-7.3.1-15.amzn2.x86_64                                 55/129
#   Verifying  : systemd-libs-219-78.amzn2.0.18.x86_64                     56/129
#   Verifying  : libmpx-7.3.1-15.amzn2.x86_64                              57/129
#   Verifying  : kernel-devel-5.10.118-111.515.amzn2.x86_64                58/129
#   Verifying  : rpm-plugin-systemd-inhibit-4.11.3-48.amzn2.0.2.x86_64     59/129
#   Verifying  : gcc-7.3.1-15.amzn2.x86_64                                 60/129
#   Verifying  : 12:dhcp-common-4.2.5-77.amzn2.1.6.x86_64                  61/129
#   Verifying  : amazon-ssm-agent-3.1.1188.0-1.amzn2.x86_64                62/129
#   Verifying  : nvidia-container-toolkit-1.10.0-1.x86_64                  63/129
#   Verifying  : dracut-033-535.amzn2.1.6.x86_64                           64/129
#   Verifying  : 2:vim-minimal-8.2.4857-1.amzn2.0.1.x86_64                 65/129
#   Verifying  : runc-1.0.0-2.amzn2.x86_64                                 66/129
#   Verifying  : libatomic-7.3.1-14.amzn2.x86_64                           67/129
#   Verifying  : rpm-build-4.11.3-40.amzn2.0.6.x86_64                      68/129
#   Verifying  : ec2-net-utils-1.6-1.amzn2.noarch                          69/129
#   Verifying  : 12:dhcp-libs-4.2.5-77.amzn2.1.5.x86_64                    70/129
#   Verifying  : gnutls-3.3.29-9.amzn2.x86_64                              71/129
#   Verifying  : aws-neuron-tools-2.0.623.0-1.x86_64                       72/129
#   Verifying  : sysctl-defaults-1.0-2.amzn2.noarch                        73/129
#   Verifying  : libitm-7.3.1-14.amzn2.x86_64                              74/129
#   Verifying  : libcilkrts-7.3.1-14.amzn2.x86_64                          75/129
#   Verifying  : libnvidia-container1-1.8.1-1.x86_64                       76/129
#   Verifying  : 2:vim-enhanced-8.2.4428-1.amzn2.0.3.x86_64                77/129
#   Verifying  : log4j-cve-2021-44228-hotpatch-1.1-16.amzn2.noarch         78/129
#   Verifying  : iproute-5.10.0-2.amzn2.0.1.x86_64                         79/129
#   Verifying  : python-devel-2.7.18-1.amzn2.0.4.x86_64                    80/129
#   Verifying  : 2:vim-filesystem-8.2.4428-1.amzn2.0.3.noarch              81/129
#   Verifying  : systemd-libs-219-78.amzn2.0.15.x86_64                     82/129
#   Verifying  : 1:openssl-1.0.2k-24.amzn2.0.2.x86_64                      83/129
#   Verifying  : tzdata-2021e-1.amzn2.noarch                               84/129
#   Verifying  : rpm-4.11.3-40.amzn2.0.6.x86_64                            85/129
#   Verifying  : cpp-7.3.1-14.amzn2.x86_64                                 86/129
#   Verifying  : kernel-devel-5.10.96-90.460.amzn2.x86_64                  87/129
#   Verifying  : 12:dhcp-common-4.2.5-77.amzn2.1.5.x86_64                  88/129
#   Verifying  : libquadmath-7.3.1-14.amzn2.x86_64                         89/129
#   Verifying  : systemd-devel-219-78.amzn2.0.15.x86_64                    90/129
#   Verifying  : nvidia-container-toolkit-1.8.1-1.x86_64                   91/129
#   Verifying  : amazon-ssm-agent-3.0.1124.0-1.amzn2.x86_64                92/129
#   Verifying  : 1:openssl-libs-1.0.2k-24.amzn2.0.2.x86_64                 93/129
#   Verifying  : gcc-7.3.1-14.amzn2.x86_64                                 94/129
#   Verifying  : gcc-c++-7.3.1-14.amzn2.x86_64                             95/129
#   Verifying  : selinux-policy-targeted-3.13.1-192.amzn2.6.7.noarch       96/129
#   Verifying  : libtiff-4.0.3-35.amzn2.0.1.x86_64                         97/129
#   Verifying  : rsyslog-8.24.0-57.amzn2.1.x86_64                          98/129
#   Verifying  : containerd-1.4.13-2.amzn2.0.1.x86_64                      99/129
#   Verifying  : tzdata-java-2021e-1.amzn2.noarch                         100/129
#   Verifying  : 2:vim-minimal-8.2.4428-1.amzn2.0.3.x86_64                101/129
#   Verifying  : systemd-sysv-219-78.amzn2.0.15.x86_64                    102/129
#   Verifying  : dracut-config-generic-033-535.amzn2.1.5.x86_64           103/129
#   Verifying  : systemd-219-78.amzn2.0.15.x86_64                         104/129
#   Verifying  : libgfortran-7.3.1-14.amzn2.x86_64                        105/129
#   Verifying  : selinux-policy-3.13.1-192.amzn2.6.7.noarch               106/129
#   Verifying  : rpm-sign-4.11.3-40.amzn2.0.6.x86_64                      107/129
#   Verifying  : nvidia-docker2-2.9.1-1.noarch                            108/129
#   Verifying  : kernel-headers-5.10.112-108.499.amzn2.x86_64             109/129
#   Verifying  : gcc-gfortran-7.3.1-14.amzn2.x86_64                       110/129
#   Verifying  : libgomp-7.3.1-14.amzn2.x86_64                            111/129
#   Verifying  : rpm-plugin-systemd-inhibit-4.11.3-40.amzn2.0.6.x86_64    112/129
#   Verifying  : 12:dhclient-4.2.5-77.amzn2.1.5.x86_64                    113/129
#   Verifying  : python2-rpm-4.11.3-40.amzn2.0.6.x86_64                   114/129
#   Verifying  : rpm-libs-4.11.3-40.amzn2.0.6.x86_64                      115/129
#   Verifying  : python-2.7.18-1.amzn2.0.4.x86_64                         116/129
#   Verifying  : system-rpm-config-9.1.0-76.amzn2.0.10.noarch             117/129
#   Verifying  : 2:vim-data-8.2.4428-1.amzn2.0.3.noarch                   118/129
#   Verifying  : libsanitizer-7.3.1-14.amzn2.x86_64                       119/129
#   Verifying  : rpm-build-libs-4.11.3-40.amzn2.0.6.x86_64                120/129
#   Verifying  : dracut-033-535.amzn2.1.5.x86_64                          121/129
#   Verifying  : libstdc++-7.3.1-14.amzn2.x86_64                          122/129
#   Verifying  : 1:openssl-devel-1.0.2k-24.amzn2.0.2.x86_64               123/129
#   Verifying  : libmpx-7.3.1-14.amzn2.x86_64                             124/129
#   Verifying  : python-libs-2.7.18-1.amzn2.0.4.x86_64                    125/129
#   Verifying  : 2:vim-common-8.2.4428-1.amzn2.0.3.x86_64                 126/129
#   Verifying  : libnvidia-container-tools-1.8.1-1.x86_64                 127/129
#   Verifying  : libgcc-7.3.1-14.amzn2.x86_64                             128/129
#   Verifying  : 2:microcode_ctl-2.1-47.amzn2.0.11.x86_64                 129/129
#
# Removed:
#   kernel-devel.x86_64 0:5.10.96-90.460.amzn2
#
# Installed:
#   ec2-net-utils.noarch 0:1.6.1-2.amzn2
#   kernel-devel.x86_64 0:5.10.118-111.515.amzn2
#
# Dependency Installed:
#   go-srpm-macros.noarch 0:3.0.15-23.amzn2.0.1
#
# Updated:
#   amazon-ssm-agent.x86_64 0:3.1.1188.0-1.amzn2
#   aws-neuron-tools.x86_64 0:2.1.4.0-1
#   containerd.x86_64 0:1.4.13-3.amzn2
#   cpp.x86_64 0:7.3.1-15.amzn2
#   dhclient.x86_64 12:4.2.5-77.amzn2.1.6
#   dhcp-common.x86_64 12:4.2.5-77.amzn2.1.6
#   dhcp-libs.x86_64 12:4.2.5-77.amzn2.1.6
#   dracut.x86_64 0:033-535.amzn2.1.6
#   dracut-config-generic.x86_64 0:033-535.amzn2.1.6
#   gcc.x86_64 0:7.3.1-15.amzn2
#   gcc-c++.x86_64 0:7.3.1-15.amzn2
#   gcc-gfortran.x86_64 0:7.3.1-15.amzn2
#   gnutls.x86_64 0:3.3.29-9.amzn2.0.1
#   iproute.x86_64 0:5.10.0-2.amzn2.0.2
#   kernel-headers.x86_64 0:5.10.118-111.515.amzn2
#   libatomic.x86_64 0:7.3.1-15.amzn2
#   libcilkrts.x86_64 0:7.3.1-15.amzn2
#   libgcc.x86_64 0:7.3.1-15.amzn2
#   libgfortran.x86_64 0:7.3.1-15.amzn2
#   libgomp.x86_64 0:7.3.1-15.amzn2
#   libitm.x86_64 0:7.3.1-15.amzn2
#   libmpx.x86_64 0:7.3.1-15.amzn2
#   libnvidia-container-tools.x86_64 0:1.10.0-1
#   libnvidia-container1.x86_64 0:1.10.0-1
#   libquadmath.x86_64 0:7.3.1-15.amzn2
#   libsanitizer.x86_64 0:7.3.1-15.amzn2
#   libstdc++.x86_64 0:7.3.1-15.amzn2
#   libtiff.x86_64 0:4.0.3-35.amzn2.0.2
#   log4j-cve-2021-44228-hotpatch.noarch 0:1.3-5.amzn2
#   microcode_ctl.x86_64 2:2.1-47.amzn2.0.12
#   nvidia-container-toolkit.x86_64 0:1.10.0-1
#   nvidia-docker2.noarch 0:2.11.0-1
#   openssl.x86_64 1:1.0.2k-24.amzn2.0.3
#   openssl-devel.x86_64 1:1.0.2k-24.amzn2.0.3
#   openssl-libs.x86_64 1:1.0.2k-24.amzn2.0.3
#   python.x86_64 0:2.7.18-1.amzn2.0.5
#   python-devel.x86_64 0:2.7.18-1.amzn2.0.5
#   python-libs.x86_64 0:2.7.18-1.amzn2.0.5
#   python2-rpm.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm-build.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm-build-libs.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm-libs.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm-plugin-systemd-inhibit.x86_64 0:4.11.3-48.amzn2.0.2
#   rpm-sign.x86_64 0:4.11.3-48.amzn2.0.2
#   rsyslog.x86_64 0:8.24.0-57.amzn2.2.0.1
#   runc.x86_64 0:1.0.3-3.amzn2
#   selinux-policy.noarch 0:3.13.1-192.amzn2.6.8
#   selinux-policy-targeted.noarch 0:3.13.1-192.amzn2.6.8
#   sysctl-defaults.noarch 0:1.0-3.amzn2
#   system-rpm-config.noarch 0:9.1.0-76.amzn2.0.14
#   systemd.x86_64 0:219-78.amzn2.0.18
#   systemd-devel.x86_64 0:219-78.amzn2.0.18
#   systemd-libs.x86_64 0:219-78.amzn2.0.18
#   systemd-sysv.x86_64 0:219-78.amzn2.0.18
#   tzdata.noarch 0:2022a-1.amzn2
#   tzdata-java.noarch 0:2022a-1.amzn2
#   vim-common.x86_64 2:8.2.4857-1.amzn2.0.1
#   vim-data.noarch 2:8.2.4857-1.amzn2.0.1
#   vim-enhanced.x86_64 2:8.2.4857-1.amzn2.0.1
#   vim-filesystem.noarch 2:8.2.4857-1.amzn2.0.1
#   vim-minimal.x86_64 2:8.2.4857-1.amzn2.0.1
#
# Replaced:
#   ec2-net-utils.noarch 0:1.6-1.amzn2
#
# Complete!
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Existing lock /var/run/yum.pid: another copy is running as pid 6969.
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory :  98 M RSS (389 MB VSZ)
#     Started: Sat Jul  2 12:31:51 2022 - 00:02 ago
#     State  : Running, pid: 6969
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory : 169 M RSS (462 MB VSZ)
#     Started: Sat Jul  2 12:31:51 2022 - 00:04 ago
#     State  : Running, pid: 6969
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory : 170 M RSS (462 MB VSZ)
#     Started: Sat Jul  2 12:31:51 2022 - 00:06 ago
#     State  : Running, pid: 6969
# neuron                                                   | 2.9 kB     00:00
# No package ffmpeg available.
# No package libsm6 available.
# No package libxext6 available.
# Error: Nothing to do

# %%
import cv2
import glob
import random
import os

img_array = []
image_dir = 'frame_images'


# create an array of available image files
for filename in os.listdir(image_dir):
    if filename.split('.')[-1]=='jpg':
        img_array.append(f'{image_dir}/{filename}')
          
# all the images should be the same size, so grab teh image size from first image
img = cv2.imread(img_array[0])
height, width, layers = img.shape
size = (width,height)

index = random.randint(0,10000000)
output_path = f'videos/movie-{index}.mp4'
out = cv2.VideoWriter(output_path,cv2.VideoWriter_fourcc(*'MP4V'), .2, size)

#random sample images and append as frames into the video
for i in range(50):
    rand_index = random.randint(0,len(img_array)-1)
    img = cv2.imread(img_array[rand_index])
    out.write(img)
out.release()

print(f'video generated at {output_path}')
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# video generated at videos/movie-6288050.mp4
